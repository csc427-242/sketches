# %% [markdown]
# implementation of a necklace
#
# demonstration for csc427-242 univ of miami
#
# 23 jan 2024
#
# burton rosenberg

# %%
#
# implementation of a necklace
# demonstration for csc427-242 univ of miami
# 23 jan 2024
# burton rosenberg
#

class NecklaceString:
    
    color = set(['w','b'])

    def __init__(self,necklace):
        self.check(necklace)
        self.necklace = necklace
    
    def check(self,n):
        assert type(n)==type(""), 'not a string'
        for b in n: 
            if b not in NecklaceString.color: 
                assert False,'not a color'
        
    def rotate(self,i):
        i = i%len(self.necklace)
        return NecklaceString(self.necklace[-i:]+self.necklace[:-i])
    
    def orbit(self):
        s = set()
        for i in range(len(self.necklace)):
            s.add(self.rotate(i).necklace)
        return s
    
class NecklaceArray:
    
    color = set(['w','b'])

    def __init__(self,necklace):
        self.check(necklace)
        self.necklace = necklace
    
    def check(self,n):
        assert type(n)==type([]), 'not an list of strings'
        for b in n: 
            if b not in NecklaceString.color: 
                assert False,'not a color'
        
    def rotate(self,i):
        i = i%len(self.necklace)
        return NecklaceArray(self.necklace[-i:]+self.necklace[:-i])
    
    def orbit(self):
        s = []
        for i in range(len(self.necklace)):
            n = self.rotate(i).necklace
            if n not in s:
                s.append(n)
        return s

# %%
n = 6

def all_strings(n):
    s = []
    if n==1:
        return ['w','b']
    else:
        r = all_strings(n-1)
        for t in r:
            s += ['b'+t]
            s += ['w'+t]
    return s

a_s = all_strings(n)
print('necklace:\torbit\n-------------------------------')
for s in a_s:
    n = NecklaceString(s)
    o = n.orbit()
    print(f'{n.necklace}:\t\t{o}')
# Out:
# necklace:	orbit
# -------------------------------
# bbbbbw:		{'bwbbbb', 'bbwbbb', 'bbbbwb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# wbbbbw:		{'wbbbbw', 'bwwbbb', 'bbwwbb', 'wwbbbb', 'bbbbww', 'bbbwwb'}
# bwbbbw:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# wwbbbw:		{'bbbwww', 'wbbbww', 'wwwbbb', 'wwbbbw', 'bbwwwb', 'bwwwbb'}
# bbwbbw:		{'wbbwbb', 'bwbbwb', 'bbwbbw'}
# wbwbbw:		{'bwbbww', 'wwbwbb', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb'}
# bwwbbw:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# wwwbbw:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# bbbwbw:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# wbbwbw:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# bwbwbw:		{'wbwbwb', 'bwbwbw'}
# wwbwbw:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# bbwwbw:		{'bwbbww', 'wwbwbb', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb'}
# wbwwbw:		{'wbwwbw', 'wwbwwb', 'bwwbww'}
# bwwwbw:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# wwwwbw:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
# bbbbww:		{'wbbbbw', 'bwwbbb', 'bbwwbb', 'wwbbbb', 'bbbbww', 'bbbwwb'}
# wbbbww:		{'bbbwww', 'wbbbww', 'wwwbbb', 'wwbbbw', 'bbwwwb', 'bwwwbb'}
# bwbbww:		{'bwbbww', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb', 'wwbwbb'}
# wwbbww:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# bbwbww:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# wbwbww:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# bwwbww:		{'wbwwbw', 'wwbwwb', 'bwwbww'}
# wwwbww:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
# bbbwww:		{'bbbwww', 'wbbbww', 'wwwbbb', 'wwbbbw', 'bbwwwb', 'bwwwbb'}
# wbbwww:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# bwbwww:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# wwbwww:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
# bbwwww:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# wbwwww:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
# bwwwww:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
# wwwwww:		{'wwwwww'}
# bbbbbb:		{'bbbbbb'}
# wbbbbb:		{'bwbbbb', 'bbwbbb', 'bbbbwb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# bwbbbb:		{'bwbbbb', 'bbwbbb', 'bbbbwb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# wwbbbb:		{'wbbbbw', 'bwwbbb', 'bbwwbb', 'wwbbbb', 'bbbbww', 'bbbwwb'}
# bbwbbb:		{'bwbbbb', 'bbwbbb', 'bbbbwb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# wbwbbb:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# bwwbbb:		{'wbbbbw', 'bwwbbb', 'bbwwbb', 'wwbbbb', 'bbbbww', 'bbbwwb'}
# wwwbbb:		{'bbbwww', 'wbbbww', 'wwwbbb', 'bbwwwb', 'wwbbbw', 'bwwwbb'}
# bbbwbb:		{'bwbbbb', 'bbbbwb', 'bbwbbb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# wbbwbb:		{'wbbwbb', 'bwbbwb', 'bbwbbw'}
# bwbwbb:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# wwbwbb:		{'bwbbww', 'wwbwbb', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb'}
# bbwwbb:		{'wbbbbw', 'bwwbbb', 'wwbbbb', 'bbwwbb', 'bbbbww', 'bbbwwb'}
# wbwwbb:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# bwwwbb:		{'bbbwww', 'wbbbww', 'wwbbbw', 'bbwwwb', 'wwwbbb', 'bwwwbb'}
# wwwwbb:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# bbbbwb:		{'bwbbbb', 'bbwbbb', 'bbbbwb', 'bbbbbw', 'wbbbbb', 'bbbwbb'}
# wbbbwb:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# bwbbwb:		{'bwbbwb', 'wbbwbb', 'bbwbbw'}
# wwbbwb:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# bbwbwb:		{'bwbbbw', 'wbbbwb', 'wbwbbb', 'bwbwbb', 'bbwbwb', 'bbbwbw'}
# wbwbwb:		{'wbwbwb', 'bwbwbw'}
# bwwbwb:		{'bwbbww', 'wwbwbb', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb'}
# wwwbwb:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# bbbwwb:		{'wbbbbw', 'bwwbbb', 'wwbbbb', 'bbwwbb', 'bbbbww', 'bbbwwb'}
# wbbwwb:		{'bwbbww', 'wwbwbb', 'bwwbwb', 'wbwbbw', 'bbwwbw', 'wbbwwb'}
# bwbwwb:		{'wwbbwb', 'wbwwbb', 'bbwbww', 'bwbwwb', 'bwwbbw', 'wbbwbw'}
# wwbwwb:		{'wbwwbw', 'wwbwwb', 'bwwbww'}
# bbwwwb:		{'bbbwww', 'wbbbww', 'wwwbbb', 'wwbbbw', 'bbwwwb', 'bwwwbb'}
# wbwwwb:		{'wwwbwb', 'wbwbww', 'wwbwbw', 'wbwwwb', 'bwbwww', 'bwwwbw'}
# bwwwwb:		{'wbbwww', 'bbwwww', 'wwwbbw', 'wwwwbb', 'bwwwwb', 'wwbbww'}
# wwwwwb:		{'bwwwww', 'wwwbww', 'wwbwww', 'wbwwww', 'wwwwwb', 'wwwwbw'}
